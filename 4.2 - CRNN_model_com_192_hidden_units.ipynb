# %% [markdown]
# # Parte do trabalho de Aprendizado de Maquina UFF 2020/01
# Codigo fonte gerado a partir de https://github.com/priya-dwivedi/Music_Genre_Classification
# Base de dados obtidos de https://github.com/mdeff/fma e https://github.com/priya-dwivedi/Music_Genre_Classification (https://os.unil.cloud.switch.ch/fma/fma_small.zip; https://drive.google.com/drive/u/0/folders/1-PTQBiz6E53uUa9LebHjds_ZQesRHEqx; https://os.unil.cloud.switch.ch/fma/fma_metadata.zip)
#
# Esta etapa consiste em treinar, validar e testar uma rede neural recorrente convolucional.
#
# Ao iniciar o treinamento a rede, irá surgir o erro "ValueError: Shapes (None, 1) and (None, 8) are incompatible". Este erro é provavelmente devido a uma etapa de "one hot encoding", que transforma o shape do dataset. Desta forma, substituiu-se o dataset processado localmente pelo já processado disponibilisado junto com o modelo (https://drive.google.com/drive/u/0/folders/1-PTQBiz6E53uUa9LebHjds_ZQesRHEqx), para que fosse possivel iniciar o treinamento. Qual a operação/algoritmo utilizado para converter o shape "(None, 1)" em "(None, 8)" será pesquisado em trabalho futuro.
#
# Durante o treinamento da rede, surgiu a seguinte mensagem inesperada: "WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr". Isto ocorreu devido à atualização do Tensosrflow/Keras ter alterado a variavel `val_acc` para `val_accuracy`. Desta forma, foi preciso alterar o nome desta variável no algoritmo.
#
# Antes de iniciar o treinamento, tambem é necessário criar a pasta referenciada no codigo, caso ainda não exista: "checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')", caso contrário a rede será treinada, mas os pesos não serão salvos e não haverá mensagem de erro.
#
# É preciso alterar a variável "filepath" para o caminho correspondente ao local onde foram baixados os exemplares e metadados:
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_train.npz')
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_valid.npz')
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/test_arr.npz')

# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 192 #96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_accuracy', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, None, 128)]       0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 56)          224
# _________________________________________________________________
# activation (Activation)      (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, None, 56)          0
# _________________________________________________________________
# dropout (Dropout)            (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_1 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 56)          224
# _________________________________________________________________
# activation_2 (Activation)    (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, None, 56)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 56)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 192)               191232
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 192)               0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                12352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 272,144
# Trainable params: 271,808
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Epoch 1/70
# 200/200 [==============================] - ETA: 0s - loss: 2.1560 - accuracy: 0.2973
# Epoch 00001: val_accuracy improved from -inf to 0.29000, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 26s 128ms/step - loss: 2.1560 - accuracy: 0.2973 - val_loss: 2.1323 - val_accuracy: 0.2900 - lr: 0.0010
# Epoch 2/70
# 200/200 [==============================] - ETA: 0s - loss: 1.9862 - accuracy: 0.3561
# Epoch 00002: val_accuracy improved from 0.29000 to 0.37250, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 123ms/step - loss: 1.9862 - accuracy: 0.3561 - val_loss: 1.9354 - val_accuracy: 0.3725 - lr: 0.0010
# Epoch 3/70
# 200/200 [==============================] - ETA: 0s - loss: 1.9126 - accuracy: 0.3816
# Epoch 00003: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.9126 - accuracy: 0.3816 - val_loss: 2.1324 - val_accuracy: 0.3212 - lr: 0.0010
# Epoch 4/70
# 200/200 [==============================] - ETA: 0s - loss: 1.8663 - accuracy: 0.3915
# Epoch 00004: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.8663 - accuracy: 0.3915 - val_loss: 1.8958 - val_accuracy: 0.3462 - lr: 0.0010
# Epoch 5/70
# 200/200 [==============================] - ETA: 0s - loss: 1.8104 - accuracy: 0.4079
# Epoch 00005: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.8104 - accuracy: 0.4079 - val_loss: 2.0864 - val_accuracy: 0.3162 - lr: 0.0010
# Epoch 6/70
# 200/200 [==============================] - ETA: 0s - loss: 1.7712 - accuracy: 0.4293
# Epoch 00006: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 126ms/step - loss: 1.7712 - accuracy: 0.4293 - val_loss: 2.0568 - val_accuracy: 0.2550 - lr: 0.0010
# Epoch 7/70
# 200/200 [==============================] - ETA: 0s - loss: 1.7374 - accuracy: 0.4284
# Epoch 00007: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 26s 128ms/step - loss: 1.7374 - accuracy: 0.4284 - val_loss: 1.9404 - val_accuracy: 0.3162 - lr: 0.0010
# Epoch 8/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6882 - accuracy: 0.4545
# Epoch 00008: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.6882 - accuracy: 0.4545 - val_loss: 2.2892 - val_accuracy: 0.2900 - lr: 0.0010
# Epoch 9/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6812 - accuracy: 0.4592
# Epoch 00009: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.6812 - accuracy: 0.4592 - val_loss: 2.6738 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 10/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6335 - accuracy: 0.4725
# Epoch 00010: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 123ms/step - loss: 1.6335 - accuracy: 0.4725 - val_loss: 2.5551 - val_accuracy: 0.2212 - lr: 0.0010
# Epoch 11/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6129 - accuracy: 0.4790
# Epoch 00011: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 24s 122ms/step - loss: 1.6129 - accuracy: 0.4790 - val_loss: 1.9001 - val_accuracy: 0.3450 - lr: 0.0010
# Epoch 12/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5954 - accuracy: 0.4876
# Epoch 00012: val_accuracy did not improve from 0.37250
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 25s 124ms/step - loss: 1.5954 - accuracy: 0.4876 - val_loss: 1.8472 - val_accuracy: 0.3338 - lr: 0.0010
# Epoch 13/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5186 - accuracy: 0.5105
# Epoch 00013: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.5186 - accuracy: 0.5105 - val_loss: 1.9878 - val_accuracy: 0.3413 - lr: 5.0000e-04
# Epoch 14/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4979 - accuracy: 0.5250
# Epoch 00014: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 123ms/step - loss: 1.4979 - accuracy: 0.5250 - val_loss: 2.0633 - val_accuracy: 0.3300 - lr: 5.0000e-04
# Epoch 15/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4743 - accuracy: 0.5317
# Epoch 00015: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 123ms/step - loss: 1.4743 - accuracy: 0.5317 - val_loss: 1.9207 - val_accuracy: 0.3725 - lr: 5.0000e-04
# Epoch 16/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4556 - accuracy: 0.5441
# Epoch 00016: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 126ms/step - loss: 1.4556 - accuracy: 0.5441 - val_loss: 1.9310 - val_accuracy: 0.3725 - lr: 5.0000e-04
# Epoch 17/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4336 - accuracy: 0.5490
# Epoch 00017: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 25s 123ms/step - loss: 1.4336 - accuracy: 0.5490 - val_loss: 2.2464 - val_accuracy: 0.2975 - lr: 5.0000e-04
# Epoch 18/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4201 - accuracy: 0.5521
# Epoch 00018: val_accuracy did not improve from 0.37250
# 200/200 [==============================] - 26s 128ms/step - loss: 1.4201 - accuracy: 0.5521 - val_loss: 2.1192 - val_accuracy: 0.3262 - lr: 5.0000e-04
# Epoch 19/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4019 - accuracy: 0.5605
# Epoch 00019: val_accuracy improved from 0.37250 to 0.43000, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 1.4019 - accuracy: 0.5605 - val_loss: 1.6343 - val_accuracy: 0.4300 - lr: 5.0000e-04
# Epoch 20/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3898 - accuracy: 0.5723
# Epoch 00020: val_accuracy did not improve from 0.43000
# 200/200 [==============================] - 25s 127ms/step - loss: 1.3898 - accuracy: 0.5723 - val_loss: 2.0689 - val_accuracy: 0.3413 - lr: 5.0000e-04
# Epoch 21/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3768 - accuracy: 0.5613
# Epoch 00021: val_accuracy did not improve from 0.43000
# 200/200 [==============================] - 25s 126ms/step - loss: 1.3768 - accuracy: 0.5613 - val_loss: 2.5543 - val_accuracy: 0.3113 - lr: 5.0000e-04
# Epoch 22/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3649 - accuracy: 0.5694
# Epoch 00022: val_accuracy did not improve from 0.43000
# 200/200 [==============================] - 25s 126ms/step - loss: 1.3649 - accuracy: 0.5694 - val_loss: 1.8690 - val_accuracy: 0.3963 - lr: 5.0000e-04
# Epoch 23/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3648 - accuracy: 0.5641
# Epoch 00023: val_accuracy did not improve from 0.43000
# 200/200 [==============================] - 25s 124ms/step - loss: 1.3648 - accuracy: 0.5641 - val_loss: 2.5175 - val_accuracy: 0.3237 - lr: 5.0000e-04
# Epoch 24/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3413 - accuracy: 0.5718
# Epoch 00024: val_accuracy did not improve from 0.43000
# 200/200 [==============================] - 25s 124ms/step - loss: 1.3413 - accuracy: 0.5718 - val_loss: 2.1286 - val_accuracy: 0.3688 - lr: 5.0000e-04
# Epoch 25/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3513 - accuracy: 0.5708
# Epoch 00025: val_accuracy improved from 0.43000 to 0.44375, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 124ms/step - loss: 1.3513 - accuracy: 0.5708 - val_loss: 1.7387 - val_accuracy: 0.4437 - lr: 5.0000e-04
# Epoch 26/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3381 - accuracy: 0.5843
# Epoch 00026: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 124ms/step - loss: 1.3381 - accuracy: 0.5843 - val_loss: 1.7898 - val_accuracy: 0.4238 - lr: 5.0000e-04
# Epoch 27/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3116 - accuracy: 0.5868
# Epoch 00027: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 125ms/step - loss: 1.3116 - accuracy: 0.5868 - val_loss: 1.9253 - val_accuracy: 0.4112 - lr: 5.0000e-04
# Epoch 28/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3062 - accuracy: 0.5888
# Epoch 00028: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 125ms/step - loss: 1.3062 - accuracy: 0.5888 - val_loss: 2.3291 - val_accuracy: 0.3512 - lr: 5.0000e-04
# Epoch 29/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3028 - accuracy: 0.5863
# Epoch 00029: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 124ms/step - loss: 1.3028 - accuracy: 0.5863 - val_loss: 1.9056 - val_accuracy: 0.3963 - lr: 5.0000e-04
# Epoch 30/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2887 - accuracy: 0.5992
# Epoch 00030: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2887 - accuracy: 0.5992 - val_loss: 1.8041 - val_accuracy: 0.4263 - lr: 5.0000e-04
# Epoch 31/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2722 - accuracy: 0.6054
# Epoch 00031: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2722 - accuracy: 0.6054 - val_loss: 1.8948 - val_accuracy: 0.4225 - lr: 5.0000e-04
# Epoch 32/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2610 - accuracy: 0.6085
# Epoch 00032: val_accuracy did not improve from 0.44375
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2610 - accuracy: 0.6085 - val_loss: 2.0152 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 33/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2638 - accuracy: 0.6093
# Epoch 00033: val_accuracy improved from 0.44375 to 0.46250, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2638 - accuracy: 0.6093 - val_loss: 1.7101 - val_accuracy: 0.4625 - lr: 5.0000e-04
# Epoch 34/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2502 - accuracy: 0.6145
# Epoch 00034: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2502 - accuracy: 0.6145 - val_loss: 2.9791 - val_accuracy: 0.3200 - lr: 5.0000e-04
# Epoch 35/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2449 - accuracy: 0.6124
# Epoch 00035: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2449 - accuracy: 0.6124 - val_loss: 2.1604 - val_accuracy: 0.3562 - lr: 5.0000e-04
# Epoch 36/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2378 - accuracy: 0.6095
# Epoch 00036: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2378 - accuracy: 0.6095 - val_loss: 2.4550 - val_accuracy: 0.3487 - lr: 5.0000e-04
# Epoch 37/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2245 - accuracy: 0.6196
# Epoch 00037: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 126ms/step - loss: 1.2245 - accuracy: 0.6196 - val_loss: 1.8794 - val_accuracy: 0.4288 - lr: 5.0000e-04
# Epoch 38/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2297 - accuracy: 0.6195
# Epoch 00038: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2297 - accuracy: 0.6195 - val_loss: 1.9634 - val_accuracy: 0.4313 - lr: 5.0000e-04
# Epoch 39/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2140 - accuracy: 0.6215
# Epoch 00039: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 127ms/step - loss: 1.2140 - accuracy: 0.6215 - val_loss: 1.9899 - val_accuracy: 0.3575 - lr: 5.0000e-04
# Epoch 40/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2166 - accuracy: 0.6231
# Epoch 00040: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 27s 135ms/step - loss: 1.2166 - accuracy: 0.6231 - val_loss: 2.0480 - val_accuracy: 0.3250 - lr: 5.0000e-04
# Epoch 41/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2025 - accuracy: 0.6207
# Epoch 00041: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.2025 - accuracy: 0.6207 - val_loss: 1.8329 - val_accuracy: 0.4400 - lr: 5.0000e-04
# Epoch 42/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2128 - accuracy: 0.6279
# Epoch 00042: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 26s 132ms/step - loss: 1.2128 - accuracy: 0.6279 - val_loss: 2.7836 - val_accuracy: 0.3063 - lr: 5.0000e-04
# Epoch 43/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1839 - accuracy: 0.6378
# Epoch 00043: val_accuracy did not improve from 0.46250
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 25s 127ms/step - loss: 1.1839 - accuracy: 0.6378 - val_loss: 2.4944 - val_accuracy: 0.3225 - lr: 5.0000e-04
# Epoch 44/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1264 - accuracy: 0.6605
# Epoch 00044: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.1264 - accuracy: 0.6605 - val_loss: 2.2591 - val_accuracy: 0.4062 - lr: 2.5000e-04
# Epoch 45/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1062 - accuracy: 0.6623
# Epoch 00045: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.1062 - accuracy: 0.6623 - val_loss: 2.2863 - val_accuracy: 0.3837 - lr: 2.5000e-04
# Epoch 46/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1101 - accuracy: 0.6633
# Epoch 00046: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 124ms/step - loss: 1.1101 - accuracy: 0.6633 - val_loss: 2.5417 - val_accuracy: 0.3725 - lr: 2.5000e-04
# Epoch 47/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.6691
# Epoch 00047: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0963 - accuracy: 0.6691 - val_loss: 1.7613 - val_accuracy: 0.4400 - lr: 2.5000e-04
# Epoch 48/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0732 - accuracy: 0.6725
# Epoch 00048: val_accuracy did not improve from 0.46250
# 200/200 [==============================] - 25s 125ms/step - loss: 1.0732 - accuracy: 0.6725 - val_loss: 2.2553 - val_accuracy: 0.4200 - lr: 2.5000e-04
# Epoch 49/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0884 - accuracy: 0.6719
# Epoch 00049: val_accuracy improved from 0.46250 to 0.47250, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 26s 131ms/step - loss: 1.0884 - accuracy: 0.6719 - val_loss: 1.7249 - val_accuracy: 0.4725 - lr: 2.5000e-04
# Epoch 50/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0753 - accuracy: 0.6734
# Epoch 00050: val_accuracy did not improve from 0.47250
# 200/200 [==============================] - 25s 127ms/step - loss: 1.0753 - accuracy: 0.6734 - val_loss: 1.8164 - val_accuracy: 0.4688 - lr: 2.5000e-04
# Epoch 51/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0669 - accuracy: 0.6777
# Epoch 00051: val_accuracy improved from 0.47250 to 0.47625, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0669 - accuracy: 0.6777 - val_loss: 1.8024 - val_accuracy: 0.4762 - lr: 2.5000e-04
# Epoch 52/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0597 - accuracy: 0.6745
# Epoch 00052: val_accuracy did not improve from 0.47625
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0597 - accuracy: 0.6745 - val_loss: 1.9170 - val_accuracy: 0.4762 - lr: 2.5000e-04
# Epoch 53/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0420 - accuracy: 0.6844
# Epoch 00053: val_accuracy did not improve from 0.47625
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0420 - accuracy: 0.6844 - val_loss: 2.1814 - val_accuracy: 0.3825 - lr: 2.5000e-04
# Epoch 54/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0368 - accuracy: 0.6861
# Epoch 00054: val_accuracy did not improve from 0.47625
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0368 - accuracy: 0.6861 - val_loss: 2.0685 - val_accuracy: 0.4600 - lr: 2.5000e-04
# Epoch 55/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0346 - accuracy: 0.6841
# Epoch 00055: val_accuracy did not improve from 0.47625
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0346 - accuracy: 0.6841 - val_loss: 1.8110 - val_accuracy: 0.4663 - lr: 2.5000e-04
# Epoch 56/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0182 - accuracy: 0.6927
# Epoch 00056: val_accuracy did not improve from 0.47625
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0182 - accuracy: 0.6927 - val_loss: 2.0197 - val_accuracy: 0.4550 - lr: 2.5000e-04
# Epoch 57/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0374 - accuracy: 0.6897
# Epoch 00057: val_accuracy improved from 0.47625 to 0.49125, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 26s 129ms/step - loss: 1.0374 - accuracy: 0.6897 - val_loss: 1.8562 - val_accuracy: 0.4913 - lr: 2.5000e-04
# Epoch 58/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0101 - accuracy: 0.6980
# Epoch 00058: val_accuracy did not improve from 0.49125
# 200/200 [==============================] - 25s 127ms/step - loss: 1.0101 - accuracy: 0.6980 - val_loss: 2.0920 - val_accuracy: 0.4238 - lr: 2.5000e-04
# Epoch 59/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0194 - accuracy: 0.6902
# Epoch 00059: val_accuracy did not improve from 0.49125
# 200/200 [==============================] - 26s 128ms/step - loss: 1.0194 - accuracy: 0.6902 - val_loss: 2.1159 - val_accuracy: 0.3975 - lr: 2.5000e-04
# Epoch 60/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9984 - accuracy: 0.6983
# Epoch 00060: val_accuracy did not improve from 0.49125
# 200/200 [==============================] - 25s 126ms/step - loss: 0.9984 - accuracy: 0.6983 - val_loss: 2.1139 - val_accuracy: 0.4600 - lr: 2.5000e-04
# Epoch 61/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0081 - accuracy: 0.6952
# Epoch 00061: val_accuracy did not improve from 0.49125
# 200/200 [==============================] - 25s 126ms/step - loss: 1.0081 - accuracy: 0.6952 - val_loss: 2.2950 - val_accuracy: 0.3900 - lr: 2.5000e-04
# Epoch 62/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9873 - accuracy: 0.7005
# Epoch 00062: val_accuracy did not improve from 0.49125
# 200/200 [==============================] - 25s 125ms/step - loss: 0.9873 - accuracy: 0.7005 - val_loss: 2.0838 - val_accuracy: 0.4125 - lr: 2.5000e-04
# Epoch 63/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9828 - accuracy: 0.7028
# Epoch 00063: val_accuracy improved from 0.49125 to 0.49500, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.9828 - accuracy: 0.7028 - val_loss: 1.9180 - val_accuracy: 0.4950 - lr: 2.5000e-04
# Epoch 64/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9964 - accuracy: 0.7014
# Epoch 00064: val_accuracy did not improve from 0.49500
# 200/200 [==============================] - 25s 125ms/step - loss: 0.9964 - accuracy: 0.7014 - val_loss: 2.0644 - val_accuracy: 0.4263 - lr: 2.5000e-04
# Epoch 65/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9638 - accuracy: 0.7079
# Epoch 00065: val_accuracy improved from 0.49500 to 0.51125, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.9638 - accuracy: 0.7079 - val_loss: 1.8774 - val_accuracy: 0.5113 - lr: 2.5000e-04
# Epoch 66/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9782 - accuracy: 0.7082
# Epoch 00066: val_accuracy did not improve from 0.51125
# 200/200 [==============================] - 25s 126ms/step - loss: 0.9782 - accuracy: 0.7082 - val_loss: 2.4338 - val_accuracy: 0.3925 - lr: 2.5000e-04
# Epoch 67/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9820 - accuracy: 0.7028
# Epoch 00067: val_accuracy did not improve from 0.51125
# 200/200 [==============================] - 25s 127ms/step - loss: 0.9820 - accuracy: 0.7028 - val_loss: 1.9884 - val_accuracy: 0.4825 - lr: 2.5000e-04
# Epoch 68/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.7141
# Epoch 00068: val_accuracy did not improve from 0.51125
# 200/200 [==============================] - 26s 130ms/step - loss: 0.9728 - accuracy: 0.7141 - val_loss: 2.2856 - val_accuracy: 0.3775 - lr: 2.5000e-04
# Epoch 69/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9566 - accuracy: 0.7116
# Epoch 00069: val_accuracy did not improve from 0.51125
# 200/200 [==============================] - 26s 129ms/step - loss: 0.9566 - accuracy: 0.7116 - val_loss: 2.3448 - val_accuracy: 0.3850 - lr: 2.5000e-04
# Epoch 70/70
# 200/200 [==============================] - ETA: 0s - loss: 0.9543 - accuracy: 0.7100
# Epoch 00070: val_accuracy did not improve from 0.51125
# 200/200 [==============================] - 25s 127ms/step - loss: 0.9543 - accuracy: 0.7100 - val_loss: 2.7174 - val_accuracy: 0.3688 - lr: 2.5000e-04

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.51      0.24      0.33       100
#  Experimental       0.41      0.48      0.44       100
#          Folk       0.40      0.87      0.55       100
#       Hip-Hop       0.72      0.28      0.40       100
#  Instrumental       0.29      0.12      0.17       100
# International       0.30      0.72      0.42       100
#           Pop       0.11      0.08      0.09       100
#          Rock       0.76      0.16      0.26       100
#
#      accuracy                           0.37       800
#     macro avg       0.44      0.37      0.33       800
#  weighted avg       0.44      0.37      0.33       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.36875

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.48      0.20      0.28       100
#  Experimental       0.23      0.41      0.29       100
#          Folk       0.20      0.23      0.21       100
#       Hip-Hop       0.52      0.81      0.63       100
#  Instrumental       0.40      0.16      0.23       100
# International       0.57      0.47      0.52       100
#           Pop       0.25      0.29      0.27       100
#          Rock       0.62      0.40      0.48       100
#
#      accuracy                           0.37       800
#     macro avg       0.41      0.37      0.36       800
#  weighted avg       0.41      0.37      0.36       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 25/25 [==============================] - 1s 28ms/step - loss: 2.2286 - accuracy: 0.3713
# [2.2285702228546143, 0.3712500035762787]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[20 20  7 21  5  7 18  2]
#  [ 4 41 12  6 10  7 13  7]
#  [ 2 42 23  0  7  6 17  3]
#  [ 4  7  1 81  0  2  5  0]
#  [ 4 32 37  1 16  2  8  0]
#  [ 3  3 16 16  1 47 11  3]
#  [ 5  7 13 24  1 11 29 10]
#  [ 0 29  7  7  0  0 17 40]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.37125

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
