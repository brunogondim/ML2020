# %% [markdown]
# # Parte do trabalho de Aprendizado de Maquina UFF 2020/01
# Codigo fonte gerado a partir de https://github.com/priya-dwivedi/Music_Genre_Classification
# Base de dados obtidos de https://github.com/mdeff/fma e https://github.com/priya-dwivedi/Music_Genre_Classification (https://os.unil.cloud.switch.ch/fma/fma_small.zip; https://drive.google.com/drive/u/0/folders/1-PTQBiz6E53uUa9LebHjds_ZQesRHEqx; https://os.unil.cloud.switch.ch/fma/fma_metadata.zip)
#
# Esta etapa consiste em treinar, validar e testar uma rede neural recorrente convolucional.
#
# Ao iniciar o treinamento a rede, irá surgir o erro "ValueError: Shapes (None, 1) and (None, 8) are incompatible". Este erro é provavelmente devido a uma etapa de "one hot encoding", que transforma o shape do dataset. Desta forma, substituiu-se o dataset processado localmente pelo já processado disponibilisado junto com o modelo (https://drive.google.com/drive/u/0/folders/1-PTQBiz6E53uUa9LebHjds_ZQesRHEqx), para que fosse possivel iniciar o treinamento. Qual a operação/algoritmo utilizado para converter o shape "(None, 1)" em "(None, 8)" será pesquisado em trabalho futuro.
#
# Durante o treinamento da rede, surgiu a seguinte mensagem inesperada: "WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr". Isto ocorreu devido à atualização do Tensosrflow/Keras ter alterado a variavel `val_acc` para `val_accuracy`. Desta forma, foi preciso alterar o nome desta variável no algoritmo.
#
# Antes de iniciar o treinamento, tambem é necessário criar a pasta referenciada no codigo, caso ainda não exista: "checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')", caso contrário a rede será treinada, mas os pesos não serão salvos e não haverá mensagem de erro.
#
# É preciso alterar a variável "filepath" para o caminho correspondente ao local onde foram baixados os exemplares e metadados:
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_train.npz')
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_valid.npz')
# * npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/test_arr.npz')

# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 6 # era 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = Conv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.4)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.4)(layer)
    
    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.4)(layer)
    
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.001)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_accuracy', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, None, 128)]       0
# _________________________________________________________________
# convolution_1 (Conv1D)       (None, None, 56)          35896
# _________________________________________________________________
# batch_normalization_28 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_28 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_29 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_29 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_30 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_30 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_4 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_31 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_31 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_5 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_32 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_32 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_6 (Conv1D)       (None, None, 56)          15736
# _________________________________________________________________
# batch_normalization_33 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_33 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 181,400
# Trainable params: 180,728
# Non-trainable params: 672
# _________________________________________________________________
# None
# Training...
# Epoch 1/70
# 200/200 [==============================] - ETA: 0s - loss: 2.3687 - accuracy: 0.2416
# Epoch 00001: val_accuracy improved from -inf to 0.25250, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 18s 89ms/step - loss: 2.3687 - accuracy: 0.2416 - val_loss: 2.3169 - val_accuracy: 0.2525 - lr: 0.0010
# Epoch 2/70
# 200/200 [==============================] - ETA: 0s - loss: 2.1521 - accuracy: 0.3409
# Epoch 00002: val_accuracy did not improve from 0.25250
# 200/200 [==============================] - 17s 86ms/step - loss: 2.1521 - accuracy: 0.3409 - val_loss: 2.5766 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/70
# 200/200 [==============================] - ETA: 0s - loss: 2.0553 - accuracy: 0.3608
# Epoch 00003: val_accuracy did not improve from 0.25250
# 200/200 [==============================] - 17s 84ms/step - loss: 2.0553 - accuracy: 0.3608 - val_loss: 2.2601 - val_accuracy: 0.2512 - lr: 0.0010
# Epoch 4/70
# 200/200 [==============================] - ETA: 0s - loss: 1.9755 - accuracy: 0.3860
# Epoch 00004: val_accuracy improved from 0.25250 to 0.37375, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 85ms/step - loss: 1.9755 - accuracy: 0.3860 - val_loss: 1.9905 - val_accuracy: 0.3738 - lr: 0.0010
# Epoch 5/70
# 200/200 [==============================] - ETA: 0s - loss: 1.9108 - accuracy: 0.4046
# Epoch 00005: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 84ms/step - loss: 1.9108 - accuracy: 0.4046 - val_loss: 2.0205 - val_accuracy: 0.3113 - lr: 0.0010
# Epoch 6/70
# 200/200 [==============================] - ETA: 0s - loss: 1.8403 - accuracy: 0.4287
# Epoch 00006: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 85ms/step - loss: 1.8403 - accuracy: 0.4287 - val_loss: 2.0704 - val_accuracy: 0.3262 - lr: 0.0010
# Epoch 7/70
# 200/200 [==============================] - ETA: 0s - loss: 1.8192 - accuracy: 0.4246
# Epoch 00007: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 85ms/step - loss: 1.8192 - accuracy: 0.4246 - val_loss: 2.3766 - val_accuracy: 0.1963 - lr: 0.0010
# Epoch 8/70
# 200/200 [==============================] - ETA: 0s - loss: 1.7724 - accuracy: 0.4460
# Epoch 00008: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 85ms/step - loss: 1.7724 - accuracy: 0.4460 - val_loss: 2.0219 - val_accuracy: 0.3125 - lr: 0.0010
# Epoch 9/70
# 200/200 [==============================] - ETA: 0s - loss: 1.7362 - accuracy: 0.4507
# Epoch 00009: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 18s 88ms/step - loss: 1.7362 - accuracy: 0.4507 - val_loss: 2.0331 - val_accuracy: 0.2738 - lr: 0.0010
# Epoch 10/70
# 200/200 [==============================] - ETA: 0s - loss: 1.7017 - accuracy: 0.4654
# Epoch 00010: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 86ms/step - loss: 1.7017 - accuracy: 0.4654 - val_loss: 2.1273 - val_accuracy: 0.2663 - lr: 0.0010
# Epoch 11/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6916 - accuracy: 0.4667
# Epoch 00011: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 86ms/step - loss: 1.6916 - accuracy: 0.4667 - val_loss: 2.0197 - val_accuracy: 0.2837 - lr: 0.0010
# Epoch 12/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6585 - accuracy: 0.4786
# Epoch 00012: val_accuracy did not improve from 0.37375
# 200/200 [==============================] - 17s 86ms/step - loss: 1.6585 - accuracy: 0.4786 - val_loss: 2.4532 - val_accuracy: 0.2212 - lr: 0.0010
# Epoch 13/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6503 - accuracy: 0.4823
# Epoch 00013: val_accuracy improved from 0.37375 to 0.40250, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 86ms/step - loss: 1.6503 - accuracy: 0.4823 - val_loss: 1.7767 - val_accuracy: 0.4025 - lr: 0.0010
# Epoch 14/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6422 - accuracy: 0.4803
# Epoch 00014: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 17s 85ms/step - loss: 1.6422 - accuracy: 0.4803 - val_loss: 1.8406 - val_accuracy: 0.3625 - lr: 0.0010
# Epoch 15/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6245 - accuracy: 0.4911
# Epoch 00015: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 17s 85ms/step - loss: 1.6245 - accuracy: 0.4911 - val_loss: 1.9420 - val_accuracy: 0.2988 - lr: 0.0010
# Epoch 16/70
# 200/200 [==============================] - ETA: 0s - loss: 1.6052 - accuracy: 0.4972
# Epoch 00016: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 18s 88ms/step - loss: 1.6052 - accuracy: 0.4972 - val_loss: 2.1983 - val_accuracy: 0.2688 - lr: 0.0010
# Epoch 17/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5948 - accuracy: 0.4998
# Epoch 00017: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5948 - accuracy: 0.4998 - val_loss: 2.1879 - val_accuracy: 0.2463 - lr: 0.0010
# Epoch 18/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5736 - accuracy: 0.5086
# Epoch 00018: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 17s 87ms/step - loss: 1.5736 - accuracy: 0.5086 - val_loss: 2.3738 - val_accuracy: 0.2488 - lr: 0.0010
# Epoch 19/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5871 - accuracy: 0.5122
# Epoch 00019: val_accuracy did not improve from 0.40250
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5871 - accuracy: 0.5122 - val_loss: 1.9233 - val_accuracy: 0.3525 - lr: 0.0010
# Epoch 20/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5789 - accuracy: 0.5106
# Epoch 00020: val_accuracy improved from 0.40250 to 0.41875, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 87ms/step - loss: 1.5789 - accuracy: 0.5106 - val_loss: 1.7788 - val_accuracy: 0.4187 - lr: 0.0010
# Epoch 21/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5676 - accuracy: 0.5113
# Epoch 00021: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5676 - accuracy: 0.5113 - val_loss: 1.8549 - val_accuracy: 0.3875 - lr: 0.0010
# Epoch 22/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5673 - accuracy: 0.5138
# Epoch 00022: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5673 - accuracy: 0.5138 - val_loss: 2.0796 - val_accuracy: 0.3225 - lr: 0.0010
# Epoch 23/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5700 - accuracy: 0.5074
# Epoch 00023: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.5700 - accuracy: 0.5074 - val_loss: 1.8670 - val_accuracy: 0.3487 - lr: 0.0010
# Epoch 24/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5488 - accuracy: 0.5202
# Epoch 00024: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.5488 - accuracy: 0.5202 - val_loss: 2.3061 - val_accuracy: 0.2325 - lr: 0.0010
# Epoch 25/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5359 - accuracy: 0.5263
# Epoch 00025: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.5359 - accuracy: 0.5263 - val_loss: 2.2611 - val_accuracy: 0.2125 - lr: 0.0010
# Epoch 26/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5389 - accuracy: 0.5222
# Epoch 00026: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5389 - accuracy: 0.5222 - val_loss: 1.9565 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 27/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5407 - accuracy: 0.5321
# Epoch 00027: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 18s 92ms/step - loss: 1.5407 - accuracy: 0.5321 - val_loss: 1.9011 - val_accuracy: 0.3187 - lr: 0.0010
# Epoch 28/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5424 - accuracy: 0.5258
# Epoch 00028: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 86ms/step - loss: 1.5424 - accuracy: 0.5258 - val_loss: 2.3839 - val_accuracy: 0.3038 - lr: 0.0010
# Epoch 29/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5170 - accuracy: 0.5283
# Epoch 00029: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.5170 - accuracy: 0.5283 - val_loss: 2.7720 - val_accuracy: 0.1787 - lr: 0.0010
# Epoch 30/70
# 200/200 [==============================] - ETA: 0s - loss: 1.5404 - accuracy: 0.5222
# Epoch 00030: val_accuracy did not improve from 0.41875
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 17s 85ms/step - loss: 1.5404 - accuracy: 0.5222 - val_loss: 2.1247 - val_accuracy: 0.2525 - lr: 0.0010
# Epoch 31/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4669 - accuracy: 0.5446
# Epoch 00031: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.4669 - accuracy: 0.5446 - val_loss: 2.7273 - val_accuracy: 0.2200 - lr: 5.0000e-04
# Epoch 32/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4184 - accuracy: 0.5640
# Epoch 00032: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.4184 - accuracy: 0.5640 - val_loss: 1.9377 - val_accuracy: 0.3762 - lr: 5.0000e-04
# Epoch 33/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4117 - accuracy: 0.5737
# Epoch 00033: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 86ms/step - loss: 1.4117 - accuracy: 0.5737 - val_loss: 2.0164 - val_accuracy: 0.3800 - lr: 5.0000e-04
# Epoch 34/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3881 - accuracy: 0.5768
# Epoch 00034: val_accuracy did not improve from 0.41875
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3881 - accuracy: 0.5768 - val_loss: 1.8581 - val_accuracy: 0.3925 - lr: 5.0000e-04
# Epoch 35/70
# 200/200 [==============================] - ETA: 0s - loss: 1.4029 - accuracy: 0.5729
# Epoch 00035: val_accuracy improved from 0.41875 to 0.47125, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 85ms/step - loss: 1.4029 - accuracy: 0.5729 - val_loss: 1.6850 - val_accuracy: 0.4712 - lr: 5.0000e-04
# Epoch 36/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3878 - accuracy: 0.5771
# Epoch 00036: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 84ms/step - loss: 1.3878 - accuracy: 0.5771 - val_loss: 1.8828 - val_accuracy: 0.3713 - lr: 5.0000e-04
# Epoch 37/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3787 - accuracy: 0.5787
# Epoch 00037: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 18s 92ms/step - loss: 1.3787 - accuracy: 0.5787 - val_loss: 3.1981 - val_accuracy: 0.2738 - lr: 5.0000e-04
# Epoch 38/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3735 - accuracy: 0.5741
# Epoch 00038: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3735 - accuracy: 0.5741 - val_loss: 1.9125 - val_accuracy: 0.3562 - lr: 5.0000e-04
# Epoch 39/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3609 - accuracy: 0.5849
# Epoch 00039: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 84ms/step - loss: 1.3609 - accuracy: 0.5849 - val_loss: 2.2323 - val_accuracy: 0.3413 - lr: 5.0000e-04
# Epoch 40/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3725 - accuracy: 0.5801
# Epoch 00040: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3725 - accuracy: 0.5801 - val_loss: 1.7600 - val_accuracy: 0.3862 - lr: 5.0000e-04
# Epoch 41/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3782 - accuracy: 0.5760
# Epoch 00041: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3782 - accuracy: 0.5760 - val_loss: 2.5391 - val_accuracy: 0.3050 - lr: 5.0000e-04
# Epoch 42/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3587 - accuracy: 0.5915
# Epoch 00042: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3587 - accuracy: 0.5915 - val_loss: 1.9008 - val_accuracy: 0.3762 - lr: 5.0000e-04
# Epoch 43/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3445 - accuracy: 0.5920
# Epoch 00043: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3445 - accuracy: 0.5920 - val_loss: 1.9905 - val_accuracy: 0.3675 - lr: 5.0000e-04
# Epoch 44/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3468 - accuracy: 0.5866
# Epoch 00044: val_accuracy did not improve from 0.47125
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3468 - accuracy: 0.5866 - val_loss: 2.0139 - val_accuracy: 0.3975 - lr: 5.0000e-04
# Epoch 45/70
# 200/200 [==============================] - ETA: 0s - loss: 1.3212 - accuracy: 0.6024
# Epoch 00045: val_accuracy did not improve from 0.47125
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 17s 85ms/step - loss: 1.3212 - accuracy: 0.6024 - val_loss: 2.0119 - val_accuracy: 0.3150 - lr: 5.0000e-04
# Epoch 46/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2817 - accuracy: 0.6181
# Epoch 00046: val_accuracy improved from 0.47125 to 0.48500, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 86ms/step - loss: 1.2817 - accuracy: 0.6181 - val_loss: 1.5680 - val_accuracy: 0.4850 - lr: 2.5000e-04
# Epoch 47/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2709 - accuracy: 0.6151
# Epoch 00047: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 85ms/step - loss: 1.2709 - accuracy: 0.6151 - val_loss: 1.7334 - val_accuracy: 0.4375 - lr: 2.5000e-04
# Epoch 48/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2613 - accuracy: 0.6126
# Epoch 00048: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 84ms/step - loss: 1.2613 - accuracy: 0.6126 - val_loss: 1.7977 - val_accuracy: 0.4375 - lr: 2.5000e-04
# Epoch 49/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2538 - accuracy: 0.6189
# Epoch 00049: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 85ms/step - loss: 1.2538 - accuracy: 0.6189 - val_loss: 1.7890 - val_accuracy: 0.4050 - lr: 2.5000e-04
# Epoch 50/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2327 - accuracy: 0.6264
# Epoch 00050: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 85ms/step - loss: 1.2327 - accuracy: 0.6264 - val_loss: 1.7123 - val_accuracy: 0.4387 - lr: 2.5000e-04
# Epoch 51/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2358 - accuracy: 0.6228
# Epoch 00051: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 84ms/step - loss: 1.2358 - accuracy: 0.6228 - val_loss: 1.9043 - val_accuracy: 0.3675 - lr: 2.5000e-04
# Epoch 52/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2231 - accuracy: 0.6329
# Epoch 00052: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 85ms/step - loss: 1.2231 - accuracy: 0.6329 - val_loss: 2.5133 - val_accuracy: 0.3600 - lr: 2.5000e-04
# Epoch 53/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2289 - accuracy: 0.6312
# Epoch 00053: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 84ms/step - loss: 1.2289 - accuracy: 0.6312 - val_loss: 2.1653 - val_accuracy: 0.3450 - lr: 2.5000e-04
# Epoch 54/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2325 - accuracy: 0.6254
# Epoch 00054: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 85ms/step - loss: 1.2325 - accuracy: 0.6254 - val_loss: 1.7418 - val_accuracy: 0.4400 - lr: 2.5000e-04
# Epoch 55/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2255 - accuracy: 0.6311
# Epoch 00055: val_accuracy did not improve from 0.48500
# 200/200 [==============================] - 17s 84ms/step - loss: 1.2255 - accuracy: 0.6311 - val_loss: 1.8020 - val_accuracy: 0.3913 - lr: 2.5000e-04
# Epoch 56/70
# 200/200 [==============================] - ETA: 0s - loss: 1.2102 - accuracy: 0.6334
# Epoch 00056: val_accuracy improved from 0.48500 to 0.48625, saving model to ./models/crnn/weights.best.h5
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 17s 86ms/step - loss: 1.2102 - accuracy: 0.6334 - val_loss: 1.6489 - val_accuracy: 0.4863 - lr: 2.5000e-04
# Epoch 57/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1676 - accuracy: 0.6534
# Epoch 00057: val_accuracy improved from 0.48625 to 0.52750, saving model to ./models/crnn/weights.best.h5
# 200/200 [==============================] - 17s 86ms/step - loss: 1.1676 - accuracy: 0.6534 - val_loss: 1.5945 - val_accuracy: 0.5275 - lr: 1.2500e-04
# Epoch 58/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1543 - accuracy: 0.6484
# Epoch 00058: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1543 - accuracy: 0.6484 - val_loss: 1.6544 - val_accuracy: 0.4775 - lr: 1.2500e-04
# Epoch 59/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1648 - accuracy: 0.6544
# Epoch 00059: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1648 - accuracy: 0.6544 - val_loss: 1.6989 - val_accuracy: 0.4650 - lr: 1.2500e-04
# Epoch 60/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1595 - accuracy: 0.6522
# Epoch 00060: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1595 - accuracy: 0.6522 - val_loss: 1.8174 - val_accuracy: 0.4437 - lr: 1.2500e-04
# Epoch 61/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1552 - accuracy: 0.6520
# Epoch 00061: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 84ms/step - loss: 1.1552 - accuracy: 0.6520 - val_loss: 1.8044 - val_accuracy: 0.3963 - lr: 1.2500e-04
# Epoch 62/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1450 - accuracy: 0.6609
# Epoch 00062: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 86ms/step - loss: 1.1450 - accuracy: 0.6609 - val_loss: 1.6390 - val_accuracy: 0.4913 - lr: 1.2500e-04
# Epoch 63/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1419 - accuracy: 0.6517
# Epoch 00063: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1419 - accuracy: 0.6517 - val_loss: 1.6952 - val_accuracy: 0.4975 - lr: 1.2500e-04
# Epoch 64/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1320 - accuracy: 0.6600
# Epoch 00064: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1320 - accuracy: 0.6600 - val_loss: 1.6351 - val_accuracy: 0.4512 - lr: 1.2500e-04
# Epoch 65/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1362 - accuracy: 0.6614
# Epoch 00065: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1362 - accuracy: 0.6614 - val_loss: 1.6197 - val_accuracy: 0.4925 - lr: 1.2500e-04
# Epoch 66/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1349 - accuracy: 0.6652
# Epoch 00066: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1349 - accuracy: 0.6652 - val_loss: 1.5539 - val_accuracy: 0.4750 - lr: 1.2500e-04
# Epoch 67/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1214 - accuracy: 0.6642
# Epoch 00067: val_accuracy did not improve from 0.52750
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 17s 84ms/step - loss: 1.1214 - accuracy: 0.6642 - val_loss: 1.8912 - val_accuracy: 0.4137 - lr: 1.2500e-04
# Epoch 68/70
# 200/200 [==============================] - ETA: 0s - loss: 1.0992 - accuracy: 0.6742
# Epoch 00068: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 84ms/step - loss: 1.0992 - accuracy: 0.6742 - val_loss: 1.6140 - val_accuracy: 0.4737 - lr: 6.2500e-05
# Epoch 69/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1145 - accuracy: 0.6694
# Epoch 00069: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 84ms/step - loss: 1.1145 - accuracy: 0.6694 - val_loss: 1.7099 - val_accuracy: 0.4400 - lr: 6.2500e-05
# Epoch 70/70
# 200/200 [==============================] - ETA: 0s - loss: 1.1054 - accuracy: 0.6722
# Epoch 00070: val_accuracy did not improve from 0.52750
# 200/200 [==============================] - 17s 85ms/step - loss: 1.1054 - accuracy: 0.6722 - val_loss: 1.5855 - val_accuracy: 0.4888 - lr: 6.2500e-05

# %%
show_summary_stats(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.53      0.44      0.48       100
#  Experimental       0.37      0.64      0.47       100
#          Folk       0.68      0.52      0.59       100
#       Hip-Hop       0.74      0.60      0.66       100
#  Instrumental       0.40      0.21      0.27       100
# International       0.58      0.68      0.63       100
#           Pop       0.12      0.14      0.13       100
#          Rock       0.65      0.68      0.66       100
#
#      accuracy                           0.49       800
#     macro avg       0.51      0.49      0.49       800
#  weighted avg       0.51      0.49      0.49       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.48875

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)

# %%
npzfile = np.load('C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.69      0.38      0.49       100
#  Experimental       0.24      0.34      0.28       100
#          Folk       0.20      0.22      0.21       100
#       Hip-Hop       0.79      0.63      0.70       100
#  Instrumental       0.34      0.20      0.25       100
# International       0.48      0.61      0.54       100
#           Pop       0.33      0.28      0.30       100
#          Rock       0.44      0.62      0.51       100
#
#      accuracy                           0.41       800
#     macro avg       0.44      0.41      0.41       800
#  weighted avg       0.44      0.41      0.41       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9085 - accuracy: 0.4100
# [1.90851628780365, 0.4099999964237213]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[38 11  6  3  2 19 13  8]
#  [ 3 34 14  2 17 12  5 13]
#  [ 0 47 22  0  9  7  6  9]
#  [ 6  9  2 63  0 10  6  4]
#  [ 3 19 38  1 20  3 11  5]
#  [ 2  0 18  3  2 61  4 10]
#  [ 3  8  5  8  4 14 28 30]
#  [ 0 14  7  0  4  0 13 62]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.41

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
