# %% [markdown]
# # Parte do trabalho de Aprendizado de Maquina UFF 2020/01
# Codigo fonte gerado a partir de https://github.com/priya-dwivedi/Music_Genre_Classification
# Base de dados obtidos de https://github.com/mdeff/fma e https://github.com/priya-dwivedi/Music_Genre_Classification (https://os.unil.cloud.switch.ch/fma/fma_small.zip; https://drive.google.com/drive/u/0/folders/1-PTQBiz6E53uUa9LebHjds_ZQesRHEqx; https://os.unil.cloud.switch.ch/fma/fma_metadata.zip)
#
# Esta etapa consiste em carregar e analisar os metadados, caracteristicas e rotulos (https://os.unil.cloud.switch.ch/fma/fma_metadata.zip) referentes aos dados de audio (https://os.unil.cloud.switch.ch/fma/fma_small.zip). Não há manipulação dos arquivos de audio em si. Estes já foram pre-processados.
#
# É preciso alterar a variável "filepath" para o caminho correspondente ao local onde foram baixados os metadados:
# * filepath = 'C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/fma_metadata/tracks.csv'
# * filepath = 'C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/fma_metadata/features.csv'
#
# Os metadados do dataset possuem mais informações do que o dataset analisado. O presente dataset possui 8.000 registros, e faz parte de um conjunto de datasets que possui ao total 106.574 registros. Desta forma, os metadados são filtrados e apenas algumas informações são aproveitadas.
#
# Ao total, são analisados 8 gereros de musica: Instrumental, Experimental, Hip-Hop, Folk, Electronic, International, Pop, e Rock. Cada genero possui 1.000 amostras. O conjunto de treinamento possui 6.400 amostras, o de validação possui 800 amostras e o de teste também possui 800 amostras.
#
# Ao final, é feito um grafico de dispersão de comparação de caracteristica de 2 estilos musicais com base nas caracteristicas dos coeficientes mfcc, com redução da dimensionalidade para 2, para que seja "desenhavel" a visualização dos dados, ja que o mfcc possui 140 parametros. Como há perda de informação, a visualização apenas serve para se ter uma noção do nivel de semelhança entre os generos analisados. No código original "small = tracks['set', 'subset'] <= 'small'" na pratica está analisando todo o data set, pois esta expressão retorna "TRUE" para todas as amostras. Para se analisar apenas os 8.000 exemplares, deve-se substituir "<=" por "==". Em termos pratico, entretanto, não faz diferença.

# %%
import pandas as pd
import os
import ast

import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
def load(filepath):

    filename = os.path.basename(filepath)

    if 'features' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'echonest' in filename:
        return pd.read_csv(filepath, index_col=0, header=[0, 1, 2])

    if 'genres' in filename:
        return pd.read_csv(filepath, index_col=0)

    if 'tracks' in filename:
        tracks = pd.read_csv(filepath, index_col=0, header=[0, 1])

        COLUMNS = [('track', 'tags'), ('album', 'tags'), ('artist', 'tags'),
                   ('track', 'genres'), ('track', 'genres_all'),
                   ('track', 'genres_top')]
        for column in COLUMNS:
            tracks[column] = tracks[column].map(ast.literal_eval)

        COLUMNS = [('track', 'date_created'), ('track', 'date_recorded'),
                   ('album', 'date_created'), ('album', 'date_released'),
                   ('artist', 'date_created'), ('artist', 'active_year_begin'),
                   ('artist', 'active_year_end')]
        for column in COLUMNS:
            tracks[column] = pd.to_datetime(tracks[column])

        SUBSETS = ('small', 'medium', 'large')
        tracks['set', 'subset'] = tracks['set', 'subset'].astype(
                'category', categories=SUBSETS, ordered=True)

        COLUMNS = [('track', 'license'), ('artist', 'bio'),
                   ('album', 'type'), ('album', 'information')]
        for column in COLUMNS:
            tracks[column] = tracks[column].astype('category')

        return tracks

# %%
# Directory where mp3 are stored.
filepath = 'C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/fma_metadata/tracks.csv'
tracks = pd.read_csv(filepath, index_col=0, header=[0, 1])
tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# ...

# %%
list(tracks)
# Out:
# [('album', 'comments'),
#  ('album', 'date_created'),
#  ('album', 'date_released'),
#  ('album', 'engineer'),
#  ('album', 'favorites'),
#  ('album', 'id'),
#  ('album', 'information'),
#  ('album', 'listens'),
#  ('album', 'producer'),
#  ('album', 'tags'),
#  ('album', 'title'),
#  ('album', 'tracks'),
#  ('album', 'type'),
#  ('artist', 'active_year_begin'),
#  ('artist', 'active_year_end'),
#  ('artist', 'associated_labels'),
#  ('artist', 'bio'),
#  ('artist', 'comments'),
#  ('artist', 'date_created'),
#  ('artist', 'favorites'),
#  ('artist', 'id'),
#  ('artist', 'latitude'),
#  ('artist', 'location'),
#  ('artist', 'longitude'),
#  ('artist', 'members'),
#  ('artist', 'name'),
#  ('artist', 'related_projects'),
#  ('artist', 'tags'),
#  ('artist', 'website'),
#  ('artist', 'wikipedia_page'),
#  ('set', 'split'),
#  ('set', 'subset'),
#  ('track', 'bit_rate'),
#  ('track', 'comments'),
#  ('track', 'composer'),
#  ('track', 'date_created'),
#  ('track', 'date_recorded'),
# ...

# %%
keep_cols = [('set', 'split'),
('set', 'subset'),('track', 'genre_top'), ('track', 'genres')]

df_all = tracks[keep_cols]
df_all = df_all[df_all[('set', 'subset')] == 'small']
df_all.head()
# Out:
#                set            track
#              split subset genre_top genres
# track_id
# 2         training  small   Hip-Hop   [21]
# 5         training  small   Hip-Hop   [21]
# 10        training  small       Pop   [10]
# 140       training  small      Folk   [17]
# 141       training  small      Folk   [17]

# %%
df_all.shape
# Out:
# (8000, 4)

# %%
df_all[('track', 'genre_top')].value_counts()
# Out:
# Rock             1000
# International    1000
# Experimental     1000
# Folk             1000
# Electronic       1000
# Hip-Hop          1000
# Instrumental     1000
# Pop              1000
# Name: (track, genre_top), dtype: int64

# %%
df_all[('set', 'split')].value_counts()
# Out:
# training      6400
# test           800
# validation     800
# Name: (set, split), dtype: int64

# %%
filepath = 'C:/Users/bruno/Desktop/aprendizado_de_maquina/seminario/ML2020_dados/fma_metadata/features.csv'
features = pd.read_csv(filepath, index_col=0,header=[0, 1, 2], skip_blank_lines=True )

# %%
features.head()
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 3             1.888963  0.760539  0.345297  2.295201  1.654031  0.067592
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
# 10            3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411
# 20           -0.193837 -0.198527  0.201546  0.258556  0.775204  0.084794
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# track_id                                            ...
# 2           1.481593  2.691455  0.866868  1.341231  ...  0.054125  0.012226
# ...

# %%
mfcc = features['mfcc']
mfcc.head()
# Out:
# statistics   kurtosis                                                    \
# number             01        02        03        04        05        06
# track_id
# 2            3.856789  1.541901  0.000816  0.330728  0.118731 -0.342687
# 3            4.296755  1.399977  0.112535 -0.211170  0.032953 -0.023489
# 5            2.624517  2.415293  0.440233 -0.782131 -0.771069 -0.724216
# 10           5.076893  1.161854  2.095651  1.372743 -0.203574 -0.345354
# 20          11.880132  4.085320  0.002655  1.518562  0.181947  0.339014
#
# statistics                                          ...        std             \
# number            07        08        09        10  ...         11         12
# track_id                                            ...
# 2          -0.259252  0.146735  0.410656 -0.162872  ...  10.059609   8.601942
# 3           0.150404  0.046454  0.033484 -0.064596  ...   8.771966  10.026867
# 5           0.090260  0.152119  0.261731 -0.608905  ...   8.863638   9.581952
# ...

# %%
mfcc.shape
# Out:
# (106574, 140)

# %%
small = tracks['set', 'subset'] <= 'small'
genre1 = tracks['track', 'genre_top'] == 'Instrumental'
genre2 = tracks['track', 'genre_top'] == 'Hip-Hop'

print(small.shape, genre1.shape, genre2.shape)

X = features.loc[small & (genre1 | genre2), 'mfcc']
X = skl.decomposition.PCA(n_components=2).fit_transform(X)

y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', alpha=0.5)
plt.show()
X.shape, y.shape
# Out:
# (106574,) (106574,) (106574,)
# ((5631, 2), (5631,))

# %%
genre2.head()
# Out:
# track_id
# 2      True
# 3      True
# 5      True
# 10    False
# 20    False
# Name: (track, genre_top), dtype: bool

# %%
small.head()
# Out:
# track_id
# 2     True
# 3     True
# 5     True
# 10    True
# 20    True
# Name: (set, subset), dtype: bool

# %% [markdown]
# Explorando outras visualizações: Instrumental, Experimental, Hip-Hop, Folk, Electronic, International, Pop, e Rock

# %%
small = tracks['set', 'subset'] <= 'small'
genre1 = tracks['track', 'genre_top'] == 'Instrumental'
genre2 = tracks['track', 'genre_top'] == 'Rock'

print(small.shape, genre1.shape, genre2.shape)

X = features.loc[small & (genre1 | genre2), 'mfcc']
X = skl.decomposition.PCA(n_components=2).fit_transform(X)

y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', alpha=0.5)
plt.show()
X.shape, y.shape
# Out:
# (106574,) (106574,) (106574,)
# ((16261, 2), (16261,))

# %%
small = tracks['set', 'subset'] == 'small'
genre1 = tracks['track', 'genre_top'] == 'Instrumental'
genre2 = tracks['track', 'genre_top'] == 'Rock'

print(small.shape, genre1.shape, genre2.shape)

X = features.loc[small & (genre1 | genre2), 'mfcc']
X = skl.decomposition.PCA(n_components=2).fit_transform(X)

y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', alpha=0.5)
plt.show()
X.shape, y.shape
# Out:
# (106574,) (106574,) (106574,)
# ((2000, 2), (2000,))
